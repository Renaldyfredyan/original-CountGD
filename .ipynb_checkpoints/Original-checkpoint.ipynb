# %%
import os
os.chdir('/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD/')
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD

# %%
# !CUDA_VISIBLE_DEVICES=7 torchrun --nproc_per_node=1 main.py \
--output_dir ./countgd_val \
-c config/cfg_fsc147_val.py \
--eval \
--datasets config/datasets_fsc147_val.json \
--pretrain_model_path checkpoints/checkpoint_fsc147_best.pth \
--options text_encoder_type=checkpoints/bert-base-uncased
# Out:
# world size: 1, rank: 0, local rank: 0
# {
#   "CUDA_VISIBLE_DEVICES": "7",
#   "SHELL": "/bin/bash",
#   "CONDA_EXE": "/opt/miniconda/bin/conda",
#   "_CE_M": "",
#   "PWD": "/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD",
#   "LOGNAME": "renaldy_fredyan",
#   "CONDA_PREFIX": "/opt/miniconda/envs/Rey1",
#   "JPY_SESSION_NAME": "/home/renaldy_fredyan/PhDResearch/CountGD/Original.ipynb",
#   "_": "/opt/miniconda/envs/Rey1/bin/torchrun",
#   "MOTD_SHOWN": "pam",
#   "HOME": "/home/renaldy_fredyan",
#   "LANG": "en_US.UTF-8",
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 torchrun --nproc_per_node=1 main.py \
--output_dir ./countgd_test \
-c config/cfg_fsc147_test.py \
--eval \
--datasets config/datasets_fsc147_test.json \
--pretrain_model_path checkpoints/checkpoint_fsc147_best.pth \
--options text_encoder_type=checkpoints/bert-base-uncased
# Out:
# world size: 1, rank: 0, local rank: 0
# {
#   "CUDA_VISIBLE_DEVICES": "7",
#   "SHELL": "/bin/bash",
#   "CONDA_EXE": "/opt/miniconda/bin/conda",
#   "_CE_M": "",
#   "PWD": "/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD",
#   "LOGNAME": "renaldy_fredyan",
#   "CONDA_PREFIX": "/opt/miniconda/envs/Rey1",
#   "JPY_SESSION_NAME": "/home/renaldy_fredyan/PhDResearch/CountGD/Original.ipynb",
#   "_": "/opt/miniconda/envs/Rey1/bin/torchrun",
#   "MOTD_SHOWN": "pam",
#   "HOME": "/home/renaldy_fredyan",
#   "LANG": "en_US.UTF-8",
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 torchrun --nproc_per_node=1 main_inference.py --output_dir ./countgd_val \
-c config/cfg_fsc147_val.py --eval --datasets config/datasets_fsc147_val.json \
--pretrain_model_path checkpoints/checkpoint_fsc147_best.pth --options text_encoder_type=checkpoints/bert-base-uncased \
--remove_bad_exemplar --amp
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# world size: 1, rank: 0, local rank: 0
# {
#   "CUDA_VISIBLE_DEVICES": "7",
#   "SHELL": "/bin/bash",
#   "CONDA_EXE": "/opt/miniconda/bin/conda",
#   "_CE_M": "",
#   "TMUX": "/tmp/tmux-1010/default,192425,0",
#   "PWD": "/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD",
#   "LOGNAME": "renaldy_fredyan",
#   "CONDA_PREFIX": "/opt/miniconda/envs/Rey1",
#   "JPY_SESSION_NAME": "/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD/Original.ipynb",
#   "_": "/opt/miniconda/envs/Rey1/bin/torchrun",
#   "MOTD_SHOWN": "pam",
#   "HOME": "/home/renaldy_fredyan",
#   "LANG": "en_US.UTF-8",
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 torchrun --nproc_per_node=1 main_inference.py --output_dir ./countgd_test \
-c config/cfg_fsc147_test.py --eval --datasets config/datasets_fsc147_test.json \
--pretrain_model_path checkpoints/checkpoint_fsc147_best.pth --options text_encoder_type=checkpoints/bert-base-uncased \
--remove_bad_exemplar
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# world size: 1, rank: 0, local rank: 0
# {
#   "CUDA_VISIBLE_DEVICES": "7",
#   "SHELL": "/bin/bash",
#   "CONDA_EXE": "/opt/miniconda/bin/conda",
#   "_CE_M": "",
#   "TMUX": "/tmp/tmux-1010/default,192425,0",
#   "PWD": "/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD",
#   "LOGNAME": "renaldy_fredyan",
#   "CONDA_PREFIX": "/opt/miniconda/envs/Rey1",
#   "JPY_SESSION_NAME": "/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD/Original.ipynb",
#   "_": "/opt/miniconda/envs/Rey1/bin/torchrun",
#   "MOTD_SHOWN": "pam",
#   "HOME": "/home/renaldy_fredyan",
#   "LANG": "en_US.UTF-8",
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 torchrun --nproc_per_node=1 main_inference.py --output_dir ./countgd_val \
-c config/cfg_fsc147_val.py --eval --datasets config/datasets_fsc147_val.json \
--pretrain_model_path checkpoints/checkpoint_fsc147_best.pth --options text_encoder_type=checkpoints/bert-base-uncased \
--sam_tt_norm --remove_bad_exemplar
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# world size: 1, rank: 0, local rank: 0
# {
#   "CUDA_VISIBLE_DEVICES": "7",
#   "SHELL": "/bin/bash",
#   "CONDA_EXE": "/opt/miniconda/bin/conda",
#   "_CE_M": "",
#   "TMUX": "/tmp/tmux-1010/default,192425,0",
#   "PWD": "/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD",
#   "LOGNAME": "renaldy_fredyan",
#   "CONDA_PREFIX": "/opt/miniconda/envs/Rey1",
#   "JPY_SESSION_NAME": "/home/renaldy_fredyan/PhDResearch/CountGD/original-CountGD/Original.ipynb",
#   "_": "/opt/miniconda/envs/Rey1/bin/torchrun",
#   "MOTD_SHOWN": "pam",
#   "HOME": "/home/renaldy_fredyan",
#   "LANG": "en_US.UTF-8",
# ...
